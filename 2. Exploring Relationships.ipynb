# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# check version (3.1.1 is bugged)

matplotlib.__version__
# Out:
# '3.7.0'

# %%
# this option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
# set path

path=r'C:\Users\t3mar\Career Foundry\Data Analytics\Project 6 Citibike'

# %%
# import data

rds_ops = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared', 'Rides & Operations.pkl'))

# %%
rds_ops.shape
# Out:
# (979515, 36)

# %%
# create a correlation matrix using pandas

rds_ops.corr()
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_11608\3916273439.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rds_ops.corr()
#                           start_lat  start_lng   end_lat   end_lng  \
# start_lat                  1.000000   0.486302  0.673498  0.410630
# start_lng                  0.486302   1.000000  0.418875  0.619164
# end_lat                    0.673498   0.418875  1.000000  0.491680
# end_lng                    0.410630   0.619164  0.491680  1.000000
# rebalances                -0.008013   0.018431 -0.005307  0.014787
# stations_active_eom       -0.001339  -0.008745 -0.001745 -0.008980
# technician_visits          0.006554  -0.016999  0.004637 -0.015138
# reported_station_malfx     0.002311  -0.001269  0.002232 -0.001243
# reported_dock_malfx        0.000636   0.001918  0.000864  0.001343
# ...

# %%
# create a correlation heatmap using matplotlib

plt.matshow(rds_ops.corr())
plt.show()
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_11608\3613406182.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(rds_ops.corr())

# %%
# save figure

plt.matshow(rds_ops.corr())
plt.savefig("out.png") 

# This will save the image in the working directory. 
#If you don't know what this directory is the next line will show you how to check
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_11608\3673908344.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(rds_ops.corr())

# %%
# current dir

cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\t3mar\\Career Foundry\\Data Analytics\\Project 6 CitiBike\\03 Scripts'

# %%
# add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(rds_ops.corr(),fignum=f.number) # type of plot
plt.xticks(range(22), corr.columns, fontsize=10, rotation=90) # x axis labels
plt.yticks(range(22), corr.columns, fontsize=10) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=10) # add font size
plt.title('Correlation Matrix', fontsize=10) # add title
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_11608\1971048065.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(rds_ops.corr(),fignum=f.number) # type of plot
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 f = plt.figure(figsize=(8, 8)) # figure size
#       4 plt.matshow(rds_ops.corr(),fignum=f.number) # type of plot
# ----> 5 plt.xticks(range(22), corr.columns, fontsize=10, rotation=90) # x axis labels
#       6 plt.yticks(range(22), corr.columns, fontsize=10) # y axis labels
#       7 cb = plt.colorbar() # add a colour legend (called colorbar)
#
# NameError: name 'corr' is not defined

# %%
# create a subplot with matplotlib

f,ax = plt.subplots(figsize=(18,18))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(rds_ops.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 

#place the correlation coefficients onto the heatmap.
# Out:
# C:\Users\t3mar\AppData\Local\Temp\ipykernel_11608\2584658945.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = sns.heatmap(rds_ops.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to

# %%
# create a scatterplot for the most important correlations

sns.lmplot(x = 'end_lat', y = 'start_lat', data = rds_ops)

# %%
sns.lmplot(x = 'end_lng', y = 'start_lng', data = rds_ops)

# %%
sns.lmplot(x = 'abandon_call_rate', y = 'refunds_and_discounts', data = rds_ops)

# %%
sns.lmplot(x = 'overflow_calls_processed', y = 'refunds_and_discounts', data = rds_ops)

# %%
sns.lmplot(x = 'rebalances', y = 'calls_per_100_rides', data = rds_ops)

# %%
sns.lmplot(x = 'stations_active_eom', y = 'calls_per_100_rides', data = rds_ops)

# %%
sns.lmplot(x = 'reported_station_malfx', y = 'stations_active_eom', data = rds_ops)

# %%
sns.lmplot(x = 'station_uptime', y = 'abandon_call_rate', data = rds_ops)

# %%
# create subsets

subset1 = rds_ops[['stations_active_eom', 'reported_station_malfx', 'station_uptime', 'abandon_call_rate']]

# %%
subset2 = rds_ops[['calls_per_100_rides', 'refunds_and_discounts', 'rebalances', 'abandon_call_rate']]

# %%
subset3 = rds_ops[['net_loss_bikes','refunds_and_discounts', 'emails', 'abandon_call_rate']]

# %%
subset4 = rds_ops[['customer_service_calls', 'overflow_calls_processed', 'emails','abandon_call_rate']]

# %%
# create pair plots

pp1 = sns.pairplot(subset1)

# %%
pp2 = sns.pairplot(subset2)

# %%
pp3 = sns.pairplot(subset3)

# %%
pp3 = sns.pairplot(subset4)

# %% [markdown]
# ### The abandoned calls category is intriguing to me because of its seems to have varying correlations with related categories.

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(rds_ops['start_lng'], bins = 5, kde = True)
# Out:
# <Axes: xlabel='start_lng', ylabel='Count'>

# %%
sns.histplot(rds_ops['start_lat'], bins = 5, kde = True)
# Out:
# <Axes: xlabel='start_lat', ylabel='Count'>

# %%
sns.histplot(rds_ops['end_lng'], bins = 5, kde = True)
# Out:
# <Axes: xlabel='end_lng', ylabel='Count'>

# %%
sns.histplot(rds_ops['end_lat'], bins = 5, kde = True)
# Out:
# <Axes: xlabel='end_lat', ylabel='Count'>

# %% [markdown]
# ### Most people start at stations with a more similar longitude than lattitude which makes sense based on the shape of manhattan.

# %%
# Create a categorical plot in seaborn using the categories above

sns.set(style="ticks")
g = sns.catplot(x="stations_active_eom", y="station_uptime", hue="abandon_call_rate", data=rds_ops)

# %% [markdown]
# ### Hypothesis: 66% of total abandonned calls are when station_active_eom is less than 100.
